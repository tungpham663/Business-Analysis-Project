# %%
from groq import Groq
from paragraphs_db import process_and_store_articles, search_samples_by_keyword, check_keyword_in_db
from api_key import API_KEY

# %%
client = Groq(api_key=API_KEY)
MODEL = "llama-3.3-70b-versatile"

# %%
articles = ["https://finance.yahoo.com/news/blockchain-will-be-a-game-changer-for-independent-artists-web3-media-president-says-170950256.html",
"https://finance.yahoo.com/news/memecoins-lose-momentum-defi-tokens-131638597.html",
"https://finance.yahoo.com/news/microstrategy-spends-54-billion-buying-another-55000-bitcoins-shares-slide-165131332.html",
"https://finance.yahoo.com/news/feds-preferred-inflation-gauge-highlights-holiday-shortened-trading-week-what-to-know-this-week-122846140.html",
"https://finance.yahoo.com/news/bitcoin-isnt-frothy-even-with-this-rally--the-kimchi-premium-helps-explain-why-110059272.html",
"https://finance.yahoo.com/news/talking-bitcoin-at-thanksgiving-is-different-this-time-110006525.html",
"https://finance.yahoo.com/news/forget-bitcoin-microstrategy-500-michael-223148986.html",
"https://finance.yahoo.com/news/heres-trump-presidency-could-affect-202400334.html",
"https://finance.yahoo.com/news/fund-managers-stock-pick-focus-000300816.html",
"https://finance.yahoo.com/news/2025-bitcoin-butterfly-moment-221214934.html",
"https://www.forbes.com/sites/digital-assets/2024/12/11/circle-and-binance-become-a-stablecoin-power-couple/",
"https://www.forbes.com/sites/digital-assets/2024/12/10/the-real-altcoin-season-is-coming-in-2025/",
"https://www.forbes.com/sites/digital-assets/2024/12/10/bitcoin-and-ai-a-path-forward/",
"https://www.forbes.com/sites/cryptoconfidential/2024/12/09/bitcoin-breaks-100000-sam-bankman-frieds-prison-diary/",
"https://www.forbes.com/sites/digital-assets/2024/12/06/tiktok-and-gen-z-fuel-xrps-rise-amid-legal-optimism-and-whale-moves/",
"https://www.forbes.com/sites/tonyaevans/2024/12/05/why-bitcoins-price-bounce-isnt-the-only-question-that-matters/",
"https://www.forbes.com/sites/digital-assets/2024/12/04/bitcoin-now-poised-for-a-26-trillion-microstrategy-game-changer-as-crypto-prices-soar/",
"https://www.forbes.com/sites/digital-assets/2024/12/01/what-crypto-investors-can-expect-from-a-pro-crypto-sec/"
]

# %%
# Run the process
#process_and_store_articles(articles)

# %%
search_samples_by_keyword("Bitcoin")
# Out:
# " Focus on the Future: Now that bitcoin has surpassed the psychological $100,000 USD barrier, the next 18 to 24 months are set to be transformative, with key developments like the approval of Bitcoin ETFs expanding market access, increasing regulatory clarity boosting institutional confidence, and the 2024 halving event, which is expected to reduce bitcoin's supply by 50%, and a pro-crypto President-elect and bipartisan support for crypto legislation, driving interest, scarcity and demand, with over 80% of institutional investors expecting bitcoin's price to increase in the next 2 years "

# %% [markdown]
# <h1>Generation function</h1>

# %%
post_types={1: "News articles announcing fluctuations, shocking news, or positive news related to blockchain (exchange/crypto, token, DeFi, NFT)",
            2: "Analytical articles, forecasts, and insights about the blockchain situation",
            3: "Blockchain knowledge-sharing articles and tutorials",
            4: "Product and service introduction articles",
            5: "Interactive articles, Q&A, Challenges, Giveaways, Polls, Surveys"}

# %%
def gen_2(paragraph, keyword, model=MODEL, temperature=0.3, max_tokens=2000):
    chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "You are an blockchain technology expert."
        },
        {
            "role": "user",
            "content": (
                "You are a blockchain technology expert. Your task is to generate a **concise and professional post** "
                "based on the provided paragraph and keyword. The post must focus on **one of the following themes**:\n\n"
                "- Analysis of the blockchain topic.\n"
                "- Future predictions or opportunities.\n"
                "- Expert insights or actionable suggestions.\n\n"
                "---\n\n"
                "### Input Format:\n"
                "The input consists of:\n\n"
                "1. **Paragraph**: A short block of text describing a blockchain-related topic.\n"
                "2. **Keyword**: The primary focus of the post.\n\n"
                "**Example Input**:\n\n"
                "```vbnet\n"
                "Paragraph: \"Bitcoin's price has been influenced by various factors, including artificial intelligence (AI). "
                "As AI technology advances, it may play a more significant role in shaping the cryptocurrency market. "
                "A recent report by a digital asset research firm suggests that AI-driven trading strategies could lead to increased market volatility. "
                "However, experts believe that AI can also help mitigate risks and improve market efficiency. "
                "To move forward, it's essential to understand the relationship between Bitcoin and AI and explore ways to harness AI's potential while minimizing its risks.\"\n"
                "Keyword: Bitcoin\n"
                "```\n\n"
                "---\n\n"
                "### Output Format:\n\n"
                "The output should be a professional post with one of the following themes: **Analysis**, **Future Predictions**, or **Expert Insights**. "
                "Use the structure below:\n\n"
                "```vbnet\n"
                "**Post Title**: <A short, engaging headline summarizing the focus>\n\n"
                "**Post Content**:\n\n"
                "<Choose one of the following themes based on the input paragraph:>\n\n"
                "🔍 **Analysis**:\n"
                "<Provide a brief analysis of the keyword, focusing on key trends, developments, or insights related to the topic.>\n\n"
                "🚀 **Future Predictions**:\n"
                "<Share forward-looking predictions or opportunities related to the keyword, while discussing challenges or risks.>\n\n"
                "💡 **Expert Insights**:\n"
                "<Offer actionable advice, suggestions, or expert opinions on how businesses, developers, or investors can leverage the keyword effectively.>\n\n"
                "#<Keyword>\n"
                "```\n\n"
                "---\n\n"
                f"### Input Data:\nParagraph: \"{paragraph}\"\nKeyword: {keyword}\n\n"
                "Now generate the output in the specified format."
    )
        }
    ],
    model=model,
    temperature=temperature,
    max_tokens=max_tokens,
)
    response = chat_completion.choices[0].message.content
    return response

# %%
def gen_2_keyword(keyword, model=MODEL, temperature=0.3, max_tokens=2000):
    chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "You are a blockchain technology expert."
        },
        {
            "role": "user",
            "content": (
                "You are a blockchain technology expert. Your task is to generate a **concise and professional post** "
                "based on the provided blockchain-related keyword. The post must focus on **one of the following themes**:\n\n"
                "- Analysis of the keyword within the blockchain context.\n"
                "- Future predictions about the keyword.\n"
                "- Expert insights or actionable advice related to the keyword.\n\n"
                "You must rely on your own expertise and knowledge to create the content.\n\n"
                "---\n\n"
                "### Input Format:\n"
                "The input consists of:\n\n"
                "- **Keyword**: A single blockchain-related word or entity.\n\n"
                "**Example Input**:\n\n"
                "```makefile\n"
                "Keyword: Bitcoin\n"
                "```\n\n"
                "---\n\n"
                "### Output Format:\n\n"
                "The output should be a professional post using the following structure:\n\n"
                "```markdown\n"
                "**Post Title**: <A short, engaging headline summarizing the focus>\n\n"
                "**Post Content**:\n\n"
                "<Choose one of the following themes:>\n\n"
                "🔍 **Analysis**:\n"
                "<Provide a brief analysis of the keyword, focusing on trends, developments, and real-world applications.>\n\n"
                "🚀 **Future Predictions**:\n"
                "<Make forward-looking predictions or highlight opportunities and challenges related to the keyword.>\n\n"
                "💡 **Expert Insights**:\n"
                "<Offer actionable advice or expert suggestions for businesses, developers, or investors on leveraging the keyword effectively.>\n\n"
                "#<Keyword>\n"
                "```\n\n"
                "---\n\n"
                f"### Input Data:\nKeyword: {keyword}\n\n"
                "Now generate the output in the specified format."
            )
        }
    ],
    model=model,
    temperature=temperature,
    max_tokens=max_tokens,
)
    response = chat_completion.choices[0].message.content
    return response

# %%
def gen_3(keyword, relationships, model=MODEL, temperature=0.3, max_tokens=2000):
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "system",
                "content": "You are a Blockchain technology expert and professional content creator."
            },
            {
                "role": "user",
                "content": (
                    "### **Prompt: Blockchain Knowledge-Sharing Post (Max 200 Words)**\n"
                    "You are a Blockchain technology expert and content creator. Your task is to write a clear, concise, and professional knowledge-sharing post "
                    "(maximum 200 words) based on the provided keyword and set of relationships. The post should focus on educating readers about blockchain concepts "
                    "or providing tutorials.\n\n"
                    "### **Input**:\n"
                    "- **Keyword**: A blockchain-related term (e.g., Bitcoin, Ethereum, SEC, Layer-2 solutions).\n"
                    "- **Relationships**: A set of relationships describing interactions between entities in the following format:\n"
                    "```plaintext\n"
                    "Relationship: 'Entity A' -[Relationship]-> 'Entity B' (Description: '<Exact sentence describing the relationship>')\n"
                    "```\n\n"
                    "### **Output Format**:\n"
                    "The output must include:\n\n"
                    "**Post Title**: A short and engaging headline.\n\n"
                    "**Post Content**: A concise explanation (limited to 200 words), educating readers on the topic using the relationships provided. Use a structured flow:\n"
                    "- **Concept**: Introduce the keyword and its significance.\n"
                    "- **Key Relationships**: Highlight 1–2 relationships and their relevance.\n"
                    "- **Takeaway**: Offer a clear educational insight, tutorial tip, or practical advice.\n\n"
                    "**Hashtag**: Include a hashtag using the keyword.\n\n"
                    "---\n\n"
                    "**Example Input**:\n"
                    "```plaintext\n"
                    "Keyword: SEC\n"
                    "Relationships:\n"
                    "Relationship: 'SEC' -[attract capital]-> 'United States of America (USA)' (Description: 'An SEC that is actually approachable and open to discussions with the crypto sector about launching businesses and tokens would – virtually by default – provide a boon to the space.')\n"
                    "Relationship: 'SEC' -[provide a tailwind to]-> 'Bitcoin' (Description: 'Even if the optimism and hopes for a strongly pro-crypto SEC does not come to pass, a tempering of the aggressive regulatory-by-enforcement approach taken under outgoing chair Gary Gensler would represent a tailwind for crypto.')\n"
                    "```\n\n"
                    "**Example Output**:\n"
                    "```markdown\n"
                    "**Post Title**: How the SEC Shapes Blockchain Innovation 🌐\n\n"
                    "**Post Content**:\n"
                    "The **Securities and Exchange Commission (SEC)** plays a critical role in determining blockchain's future in the **United States of America (USA)**. "
                    "With a more approachable stance, the SEC could unlock immense capital flow into the blockchain space, boosting innovation and business growth.\n\n"
                    "For example:\n"
                    "> *\"An approachable SEC provides a boon to the crypto sector by fostering businesses and tokens.\"*\n\n"
                    "Furthermore, a shift away from aggressive regulatory enforcement can directly support major cryptocurrencies like **Bitcoin**:\n"
                    "> *\"A tempering of strict regulations would provide a tailwind for Bitcoin.\"*\n\n"
                    "### Takeaway:\n"
                    "Understanding regulatory trends helps businesses and investors prepare for growth. Monitor SEC updates to identify opportunities in blockchain and crypto investments.\n\n"
                    "#SEC\n"
                    "```\n\n"
                    "---\n\n"
                    "**Input Data**:\n"
                    f"Keyword: {keyword}\nRelationships:\n{relationships}\n\n"
                    "Now generate a clear, concise, and professional blockchain knowledge-sharing post using the input data, following the specified format."
                )
            }
        ],
        model=model,
        temperature=temperature,
        max_tokens=max_tokens,
    )
    response = chat_completion.choices[0].message.content
    return response

# %%
def gen_3_keyword(keyword, model=MODEL, temperature=0.3, max_tokens=500):
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "system",
                "content": "You are a Blockchain technology expert and professional content creator."
            },
            {
                "role": "user",
                "content": (
                    "### **Prompt: Blockchain Knowledge-Sharing Post (Max 200 Words)**\n"
                    "You are a Blockchain technology expert and content creator. Your task is to write a clear, concise, and professional knowledge-sharing post "
                    "(maximum 200 words) about the provided **blockchain-related keyword**. The post should focus on educating readers about the keyword or providing tutorials, "
                    "based on your own knowledge and expertise.\n\n"
                    "### **Input**:\n"
                    "- **Keyword**: A blockchain-related term (e.g., Bitcoin, Ethereum, SEC, Layer-2 solutions).\n\n"
                    "### **Output Format**:\n"
                    "The output must include:\n\n"
                    "**Post Title**: A short and engaging headline.\n\n"
                    "**Post Content**: A concise explanation (limited to 200 words), educating readers on the keyword. Use a structured flow:\n"
                    "- **Concept**: Introduce the keyword and its significance in the blockchain ecosystem.\n"
                    "- **Key Details**: Share important insights, applications, or developments about the keyword.\n"
                    "- **Takeaway**: Offer a clear educational insight, tutorial tip, or practical advice.\n\n"
                    "**Hashtag**: Include a hashtag using the keyword.\n\n"
                    "---\n\n"
                    "**Example Input**:\n"
                    "```plaintext\n"
                    "Keyword: Bitcoin\n"
                    "```\n\n"
                    "**Example Output**:\n"
                    "```markdown\n"
                    "**Post Title**: Bitcoin: The Pioneer of Digital Currency 🌐\n\n"
                    "**Post Content**:\n"
                    "Bitcoin is the first and most prominent cryptocurrency, introduced by Satoshi Nakamoto in 2008. It operates on a decentralized blockchain network, "
                    "eliminating intermediaries like banks for peer-to-peer transactions. With a finite supply of **21 million coins**, Bitcoin is often called *digital gold* "
                    "and is widely used as a store of value.\n\n"
                    "Bitcoin's influence extends into financial systems, enabling borderless payments and financial inclusion. Its network relies on miners who validate transactions "
                    "using **Proof-of-Work (PoW)**, ensuring security and immutability.\n\n"
                    "### Takeaway:\n"
                    "Bitcoin has revolutionized the global financial system. For beginners, understanding its decentralized nature and limited supply is key to grasping its value.\n\n"
                    "#Bitcoin\n"
                    "```\n\n"
                    "---\n\n"
                    "**Input Data**:\n"
                    f"Keyword: {keyword}\n\n"
                    "Now generate a clear, concise, and professional blockchain knowledge-sharing post using the input keyword, following the specified format."
                )
            }
        ],
        model=model,
        temperature=temperature,
        max_tokens=max_tokens,
    )
    response = chat_completion.choices[0].message.content
    return response

# %%
from graph import Neo4jGraph
#Neo4j connection details
URI = "bolt://localhost:7687"  # Replace with your Neo4j URI
USERNAME = "neo4j"             # Default username
PASSWORD = "12345678"     # Replace with your Neo4j password
graph = Neo4jGraph(URI, USERNAME, PASSWORD)

# %%
from paragraphs_db import connect_to_db, search_samples_by_keyword
connect_to_db()
# Out:
# <connection object at 0x00000146FABC2020; dsn: 'user=postgres password=xxx dbname=testDB host=localhost', closed: 0>

# %%
from graph import Neo4jGraph
# Neo4j connection details
URI = "bolt://localhost:7687"  # Replace with your Neo4j URI
USERNAME = "neo4j"             # Default username
PASSWORD = "12345678"     # Replace with your Neo4j password
graph = Neo4jGraph(URI, USERNAME, PASSWORD)

# %%
def gen_1(keyword, paragraph="", relationships=[], model=MODEL, temperature=0.3, max_tokens=500):
    paragraph = search_samples_by_keyword(keyword)
    relationships = graph.get_rel_depth2(keyword)
    chat_completion = client.chat.completions.create(
        messages=[
            {
                'role': 'system',
                'content': 'You are an advanced content generator specializing in creating engaging news articles related to blockchain events.'
            },
            {
                'role': 'user',
                'content': f"""
You are an advanced content generator specializing in creating engaging news articles related to blockchain events. Your task is to write a short **news post** about **fluctuations, shocking news, or positive news** in the blockchain industry, specifically in areas like crypto exchanges, tokens, DeFi, or NFTs.

---

### **Input**:
- **Keyword**: {keyword}
- **Paragraph**: {paragraph if paragraph else "None"}
- **Relationships**: 
{relationships if relationships else "None"}

---

### **Instructions**:
1. **Purpose**: The post must highlight key events, trends, or news that are shocking, exciting, or indicate positive fluctuations in the blockchain space.  
2. **Format**:
   - Start with a **headline** that is concise and attention-grabbing (e.g., "DeFi Tokens Soar Amid Pro-Crypto Policies Following Election Results").  
   - Use the keyword as the central theme of the post.  
   - Include information from the paragraph or relationships if provided. If no details are available, infer plausible and realistic blockchain-related news.  
3. **Tone**: Use a professional and engaging tone as seen in top financial or crypto news outlets like **CoinDesk**, **Bloomberg Crypto**, or **CoinTelegraph**.  
4. **Length**: The post should be around 80–150 words.  
5. **Highlight Impact**: Focus on how the event impacts tokens, DeFi, NFT, exchanges, or broader blockchain sentiment.
                """
            }
        ],
        model=model,
        temperature=temperature,
        max_tokens=max_tokens,
    )

    return chat_completion.choices[0].message.content

# %%
def generation(post_type, keyword):
    """
    Generate a post based on the post type and keyword.

    Parameters:
        post_type (int): The type of post to generate.
        keyword (str): The keyword to include in the post.

    Returns:
        str: The generated post.
    """
    if post_type == 1:
        return gen_1(keyword)
    elif post_type == 2:
        if check_keyword_in_db(keyword):
            paragraph = search_samples_by_keyword(keyword)
            return gen_2(paragraph, keyword)
        else:
            return gen_2_keyword(keyword)
    elif post_type == 3:
        if graph.node_exists(keyword):
            relationships = graph.get_relationships(keyword)
            return gen_3(keyword, relationships)
        else:
            return gen_3_keyword(keyword)
    elif post_type == 4:
        pass
    elif post_type == 5:
        pass

# %%
print(generation(1, "Bitcoin"))
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\result.py:620: UserWarning: Expected a result with a single record, but found multiple.
#   warn(
# ### **Bitcoin Surges as Institutional Investors Pile In**
#
# ...
